# %% [markdown]
# Question 1
# 1 Write a Python program using function concept that maps list of words into a list of integers
# representing the lengths of the corresponding words.
# Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
# Here 2,3 and 4 are the lengths of the words in the list.

# %%
# Solution
word_list = [22, 'name' ,'is', 'Abhijeet', 'khobragade']

def wordlength(word_list):
    return list(map(lambda x : len(str(x)) , word_list))

print('word lengths in array : ' + str(wordlength(word_list)))
# Out:
# word lengths in array : [2, 4, 2, 8, 10]

# %%
url = "https://www.geeksforgeeks.org/python-map-function/" # url for map function

# %%
url = "https://www.geeksforgeeks.org/python-lambda-anonymous-functions-filter-map-reduce/" # url for lambda function

# %%
# Example 
sentence = ['mjhe', 'kuch', 'kaam', 'se', 'bhar', 'jana', "pad", 'sakta', 'hai', 'aaj', 'raat', 'me']

# %%
def len_of_sentence(sentence):
    return list(map(lambda a : len(a),sentence))

# %%
len_of_sentence(sentence)
# Out:
# [4, 4, 4, 2, 4, 4, 3, 5, 3, 3, 4, 2]

# %% [markdown]
# Question 2
# 2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if
# it is a vowel, False otherwise.

# %%
# Solution
# function to check char is vowel and return true or false
def vowel_check(char):
    if(char == 'a' or char == 'e' or char == 'i' or char == 'o' or char == 'u'):
        return True
    else:
        return False

# taking user input
char = input('enter character: ')



# to start  function
if (vowel_check(char)):
    print(char,'is a vowel.')
else:
    print(char,'is not a vowel. Please try again:D')
    char = input('enter character: ')
    if (vowel_check(char)):
        print(char,'is a vowel.')
    else:
        print(char,'is not a vowel. Please try again:D')
# Out:
# t is not a vowel. Please try again:D
# i is a vowel.

# %%
while True:
    try:
        vowel = input("enter any vowel: ")
        if vowel == 'a' or vowel == 'e' or vowel == 'i' or vowel == 'o' or vowel == 'u':
            print(vowel,"this is a true vowel")
            break;
        else:
            print("this is not a vowel")
    except Exception as e :
        print(e)
    finally:
        print("koi baat nhi try karte raho")
# Out:
# this is not a vowel
# koi baat nhi try karte raho
# this is not a vowel
# koi baat nhi try karte raho
# e this is a true vowel
# koi baat nhi try karte raho
